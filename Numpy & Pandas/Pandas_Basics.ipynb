# %%
import pandas as pd
import numpy as np 
# these are the imports

# %%
df = pd.read_csv('/Users/apple/Downloads/chicago_taxi_train.csv')
df = df.loc[:, ['TRIP_MILES', 'TRIP_SECONDS', 'FARE', 'COMPANY', 'PAYMENT_TYPE', 'TIP_RATE']]
df.head(200)
# Out:
#      TRIP_MILES  TRIP_SECONDS   FARE                       COMPANY  \
# 0          2.57          2341  31.99                     Flash Cab
# 1          1.18          1074   9.75                     Flash Cab
# 2          1.29          1173  10.25                      Sun Taxi
# 3          3.70          3360  23.75       Choice Taxi Association
# 4          1.15          1044  10.00                     Flash Cab
# ..          ...           ...    ...                           ...
# 195        1.13           821   9.00  Blue Ribbon Taxi Association
# 196        0.57           414   6.00                     Flash Cab
# 197        1.22           886   9.00                  City Service
# 198        1.68          1219   9.00                      Sun Taxi
# 199        0.71           515   6.50                      Sun Taxi
#
#     PAYMENT_TYPE  TIP_RATE
# 0         Mobile       6.3
# 1    Credit Card      27.9
# 2           Cash       0.0
# 3           Cash       0.0
# ...

# %%
data = {
'patient_id': [101, 102, 103],
'age': [45, 60, 38],
'diagnosis': ['benign', 'malignant', 'benign'],
'nodule_size':[1.2, 3.5, 0.8]
} # lets assume that this is the data

df = pd.DataFrame(data)
df.head()
# this is how we handle data in the form of table
# Out:
#    patient_id  age  diagnosis  nodule_size
# 0         101   45     benign          1.2
# 1         102   60  malignant          3.5
# 2         103   38     benign          0.8
